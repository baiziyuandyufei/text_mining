# %% [markdown]
# 参考Theano官网教程，在鸢尾花数据集上训练逻辑回归多分类模型。

# %%
from sklearn.datasets import load_iris
import theano
import theano.tensor as T
import numpy

# %% [markdown]
# ## 加载数据

# %%
datasets = load_iris()
train_set_x = theano.shared(datasets.data[:,(0,2)].astype(dtype=theano.config.floatX), borrow=True)
train_set_y = T.cast(theano.shared(datasets.target.astype(dtype=theano.config.floatX),borrow=True),'int32')
valid_set_x, valid_set_y = train_set_x, train_set_y

# %% [markdown]
# ## 构建模型

# %%
# 输入数据矩阵
x = T.matrix('x')  # data, presented as rasterized images
# 输入数据类别
y = T.ivector('y')  # labels, presented as 1D vector of [int] labels

# 输入向量维度
n_in=2
# 输出向量维度
n_out=3

# 模型参数
W = theano.shared(value=numpy.zeros((n_in, n_out), dtype=theano.config.floatX),
                  name='W',
                  borrow=True)
# initialize the biases b as a vector of n_out 0s
b = theano.shared(value=numpy.zeros((n_out,), dtype=theano.config.floatX),
                  name='b',
                  borrow=True)

# 预测表达式
p_y_given_x = T.nnet.softmax(T.dot(x, W) + b)
y_pred = T.argmax(p_y_given_x, axis=1)


# 损失函数表达式
cost =  -T.mean(T.log(p_y_given_x)[T.arange(y.shape[0]), y])
# 计算梯度
g_W = T.grad(cost=cost, wrt=W)
g_b = T.grad(cost=cost, wrt=b)


# 误差表达式
errors = T.mean(T.neq(y_pred, y))

# 批次索引
index = T.lscalar()

# 一个批次所含实例数量
batch_size=150

# 学习速率
learning_rate=0.01

# 编译验证函数
validate_model = theano.function(
    inputs=[index],
    outputs=errors,
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

# 编译训练函数
train_model = theano.function(
    inputs=[index],
    outputs=cost,
    updates=[(W, W - learning_rate * g_W),
           (b, b - learning_rate * g_b)],
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

# %% [markdown]
# ## 训练模型

# %%
# compute number of minibatches for training, validation and testing
n_train_batches = train_set_x.get_value(borrow=True).shape[0] // batch_size
n_valid_batches = valid_set_x.get_value(borrow=True).shape[0] // batch_size

# 周期数
n_epochs=1000
epoch = 0
while epoch < n_epochs:
    epoch = epoch + 1
    for minibatch_index in range(n_train_batches):
        minibatch_avg_cost = train_model(minibatch_index)
        # iteration number
        iter = (epoch - 1) * n_train_batches + minibatch_index
        # compute zero-one loss on validation set
        validation_losses = [validate_model(i)
                                for i in range(n_valid_batches)]
        this_validation_loss = numpy.mean(validation_losses)

        print(
            'epoch %i, minibatch %i/%i, validation error %f %%' %
            (
                epoch,
                minibatch_index + 1,
                n_train_batches,
                this_validation_loss * 100.
            )
        )
# Out:
# epoch 1, minibatch 1/1, validation error 66.666667 %
# epoch 2, minibatch 1/1, validation error 66.666667 %
# epoch 3, minibatch 1/1, validation error 66.666667 %
# epoch 4, minibatch 1/1, validation error 66.666667 %
# epoch 5, minibatch 1/1, validation error 66.666667 %
# epoch 6, minibatch 1/1, validation error 66.666667 %
# epoch 7, minibatch 1/1, validation error 66.666667 %
# epoch 8, minibatch 1/1, validation error 66.666667 %
# epoch 9, minibatch 1/1, validation error 66.666667 %
# epoch 10, minibatch 1/1, validation error 66.666667 %
# epoch 11, minibatch 1/1, validation error 66.666667 %
# epoch 12, minibatch 1/1, validation error 66.666667 %
# epoch 13, minibatch 1/1, validation error 66.666667 %
# epoch 14, minibatch 1/1, validation error 66.666667 %
# epoch 15, minibatch 1/1, validation error 66.666667 %
# epoch 16, minibatch 1/1, validation error 66.666667 %
# epoch 17, minibatch 1/1, validation error 66.666667 %
# epoch 18, minibatch 1/1, validation error 66.666667 %
# epoch 19, minibatch 1/1, validation error 66.666667 %
# epoch 20, minibatch 1/1, validation error 66.666667 %
# epoch 21, minibatch 1/1, validation error 66.666667 %
# epoch 22, minibatch 1/1, validation error 65.333333 %
# epoch 23, minibatch 1/1, validation error 65.333333 %
# epoch 24, minibatch 1/1, validation error 63.333333 %
# epoch 25, minibatch 1/1, validation error 61.333333 %
# epoch 26, minibatch 1/1, validation error 60.000000 %
# epoch 27, minibatch 1/1, validation error 55.333333 %
# epoch 28, minibatch 1/1, validation error 49.333333 %
# epoch 29, minibatch 1/1, validation error 44.666667 %
# epoch 30, minibatch 1/1, validation error 42.666667 %
# epoch 31, minibatch 1/1, validation error 38.000000 %
# epoch 32, minibatch 1/1, validation error 37.333333 %
# epoch 33, minibatch 1/1, validation error 35.333333 %
# epoch 34, minibatch 1/1, validation error 34.666667 %
# epoch 35, minibatch 1/1, validation error 34.666667 %
# epoch 36, minibatch 1/1, validation error 34.666667 %
# epoch 37, minibatch 1/1, validation error 34.666667 %
# epoch 38, minibatch 1/1, validation error 34.666667 %
# epoch 39, minibatch 1/1, validation error 34.000000 %
# epoch 40, minibatch 1/1, validation error 34.000000 %
# epoch 41, minibatch 1/1, validation error 34.000000 %
# epoch 42, minibatch 1/1, validation error 34.000000 %
# epoch 43, minibatch 1/1, validation error 33.333333 %
# epoch 44, minibatch 1/1, validation error 33.333333 %
# epoch 45, minibatch 1/1, validation error 33.333333 %
# epoch 46, minibatch 1/1, validation error 33.333333 %
# epoch 47, minibatch 1/1, validation error 33.333333 %
# epoch 48, minibatch 1/1, validation error 33.333333 %
# epoch 49, minibatch 1/1, validation error 33.333333 %
# epoch 50, minibatch 1/1, validation error 33.333333 %
# epoch 51, minibatch 1/1, validation error 33.333333 %
# epoch 52, minibatch 1/1, validation error 33.333333 %
# epoch 53, minibatch 1/1, validation error 33.333333 %
# epoch 54, minibatch 1/1, validation error 33.333333 %
# epoch 55, minibatch 1/1, validation error 33.333333 %
# epoch 56, minibatch 1/1, validation error 33.333333 %
# epoch 57, minibatch 1/1, validation error 33.333333 %
# epoch 58, minibatch 1/1, validation error 33.333333 %
# epoch 59, minibatch 1/1, validation error 33.333333 %
# epoch 60, minibatch 1/1, validation error 33.333333 %
# epoch 61, minibatch 1/1, validation error 33.333333 %
# epoch 62, minibatch 1/1, validation error 33.333333 %
# epoch 63, minibatch 1/1, validation error 33.333333 %
# epoch 64, minibatch 1/1, validation error 33.333333 %
# epoch 65, minibatch 1/1, validation error 33.333333 %
# epoch 66, minibatch 1/1, validation error 33.333333 %
# epoch 67, minibatch 1/1, validation error 33.333333 %
# epoch 68, minibatch 1/1, validation error 33.333333 %
# epoch 69, minibatch 1/1, validation error 33.333333 %
# epoch 70, minibatch 1/1, validation error 33.333333 %
# epoch 71, minibatch 1/1, validation error 33.333333 %
# epoch 72, minibatch 1/1, validation error 33.333333 %
# epoch 73, minibatch 1/1, validation error 33.333333 %
# epoch 74, minibatch 1/1, validation error 33.333333 %
# epoch 75, minibatch 1/1, validation error 33.333333 %
# epoch 76, minibatch 1/1, validation error 33.333333 %
# epoch 77, minibatch 1/1, validation error 33.333333 %
# epoch 78, minibatch 1/1, validation error 33.333333 %
# epoch 79, minibatch 1/1, validation error 33.333333 %
# epoch 80, minibatch 1/1, validation error 33.333333 %
# epoch 81, minibatch 1/1, validation error 33.333333 %
# epoch 82, minibatch 1/1, validation error 33.333333 %
# epoch 83, minibatch 1/1, validation error 33.333333 %
# epoch 84, minibatch 1/1, validation error 33.333333 %
# epoch 85, minibatch 1/1, validation error 33.333333 %
# epoch 86, minibatch 1/1, validation error 33.333333 %
# epoch 87, minibatch 1/1, validation error 33.333333 %
# epoch 88, minibatch 1/1, validation error 33.333333 %
# epoch 89, minibatch 1/1, validation error 33.333333 %
# epoch 90, minibatch 1/1, validation error 33.333333 %
# epoch 91, minibatch 1/1, validation error 33.333333 %
# epoch 92, minibatch 1/1, validation error 33.333333 %
# epoch 93, minibatch 1/1, validation error 33.333333 %
# epoch 94, minibatch 1/1, validation error 33.333333 %
# epoch 95, minibatch 1/1, validation error 33.333333 %
# epoch 96, minibatch 1/1, validation error 33.333333 %
# epoch 97, minibatch 1/1, validation error 33.333333 %
# epoch 98, minibatch 1/1, validation error 33.333333 %
# epoch 99, minibatch 1/1, validation error 33.333333 %
# epoch 100, minibatch 1/1, validation error 33.333333 %
# epoch 101, minibatch 1/1, validation error 33.333333 %
# epoch 102, minibatch 1/1, validation error 33.333333 %
# epoch 103, minibatch 1/1, validation error 33.333333 %
# epoch 104, minibatch 1/1, validation error 33.333333 %
# epoch 105, minibatch 1/1, validation error 33.333333 %
# epoch 106, minibatch 1/1, validation error 33.333333 %
# epoch 107, minibatch 1/1, validation error 33.333333 %
# epoch 108, minibatch 1/1, validation error 33.333333 %
# epoch 109, minibatch 1/1, validation error 32.666667 %
# epoch 110, minibatch 1/1, validation error 32.666667 %
# epoch 111, minibatch 1/1, validation error 32.666667 %
# epoch 112, minibatch 1/1, validation error 32.666667 %
# epoch 113, minibatch 1/1, validation error 32.666667 %
# epoch 114, minibatch 1/1, validation error 32.666667 %
# epoch 115, minibatch 1/1, validation error 32.666667 %
# epoch 116, minibatch 1/1, validation error 32.666667 %
# epoch 117, minibatch 1/1, validation error 32.666667 %
# epoch 118, minibatch 1/1, validation error 32.666667 %
# epoch 119, minibatch 1/1, validation error 32.666667 %
# epoch 120, minibatch 1/1, validation error 32.666667 %
# epoch 121, minibatch 1/1, validation error 32.666667 %
# epoch 122, minibatch 1/1, validation error 32.666667 %
# epoch 123, minibatch 1/1, validation error 32.666667 %
# epoch 124, minibatch 1/1, validation error 32.666667 %
# epoch 125, minibatch 1/1, validation error 32.666667 %
# epoch 126, minibatch 1/1, validation error 32.666667 %
# epoch 127, minibatch 1/1, validation error 32.666667 %
# epoch 128, minibatch 1/1, validation error 32.666667 %
# epoch 129, minibatch 1/1, validation error 32.666667 %
# epoch 130, minibatch 1/1, validation error 32.666667 %
# epoch 131, minibatch 1/1, validation error 32.666667 %
# epoch 132, minibatch 1/1, validation error 32.666667 %
# epoch 133, minibatch 1/1, validation error 32.666667 %
# epoch 134, minibatch 1/1, validation error 32.666667 %
# epoch 135, minibatch 1/1, validation error 32.666667 %
# epoch 136, minibatch 1/1, validation error 32.666667 %
# epoch 137, minibatch 1/1, validation error 32.666667 %
# epoch 138, minibatch 1/1, validation error 32.000000 %
# epoch 139, minibatch 1/1, validation error 32.000000 %
# epoch 140, minibatch 1/1, validation error 32.000000 %
# epoch 141, minibatch 1/1, validation error 32.000000 %
# epoch 142, minibatch 1/1, validation error 32.000000 %
# epoch 143, minibatch 1/1, validation error 32.000000 %
# epoch 144, minibatch 1/1, validation error 32.000000 %
# epoch 145, minibatch 1/1, validation error 32.000000 %
# epoch 146, minibatch 1/1, validation error 32.000000 %
# epoch 147, minibatch 1/1, validation error 32.000000 %
# epoch 148, minibatch 1/1, validation error 32.000000 %
# epoch 149, minibatch 1/1, validation error 32.000000 %
# epoch 150, minibatch 1/1, validation error 32.000000 %
# epoch 151, minibatch 1/1, validation error 32.000000 %
# epoch 152, minibatch 1/1, validation error 32.000000 %
# epoch 153, minibatch 1/1, validation error 32.000000 %
# epoch 154, minibatch 1/1, validation error 32.000000 %
# epoch 155, minibatch 1/1, validation error 32.000000 %
# epoch 156, minibatch 1/1, validation error 32.000000 %
# epoch 157, minibatch 1/1, validation error 32.000000 %
# epoch 158, minibatch 1/1, validation error 32.000000 %
# epoch 159, minibatch 1/1, validation error 32.000000 %
# epoch 160, minibatch 1/1, validation error 32.000000 %
# epoch 161, minibatch 1/1, validation error 32.000000 %
# epoch 162, minibatch 1/1, validation error 32.000000 %
# epoch 163, minibatch 1/1, validation error 32.000000 %
# epoch 164, minibatch 1/1, validation error 32.000000 %
# epoch 165, minibatch 1/1, validation error 32.000000 %
# epoch 166, minibatch 1/1, validation error 32.000000 %
# epoch 167, minibatch 1/1, validation error 32.000000 %
# epoch 168, minibatch 1/1, validation error 32.000000 %
# epoch 169, minibatch 1/1, validation error 32.000000 %
# epoch 170, minibatch 1/1, validation error 32.000000 %
# epoch 171, minibatch 1/1, validation error 32.000000 %
# epoch 172, minibatch 1/1, validation error 32.000000 %
# epoch 173, minibatch 1/1, validation error 32.000000 %
# epoch 174, minibatch 1/1, validation error 32.000000 %
# epoch 175, minibatch 1/1, validation error 32.000000 %
# epoch 176, minibatch 1/1, validation error 31.333333 %
# epoch 177, minibatch 1/1, validation error 31.333333 %
# epoch 178, minibatch 1/1, validation error 31.333333 %
# epoch 179, minibatch 1/1, validation error 31.333333 %
# epoch 180, minibatch 1/1, validation error 31.333333 %
# epoch 181, minibatch 1/1, validation error 31.333333 %
# epoch 182, minibatch 1/1, validation error 31.333333 %
# epoch 183, minibatch 1/1, validation error 31.333333 %
# epoch 184, minibatch 1/1, validation error 31.333333 %
# epoch 185, minibatch 1/1, validation error 31.333333 %
# epoch 186, minibatch 1/1, validation error 31.333333 %
# epoch 187, minibatch 1/1, validation error 31.333333 %
# epoch 188, minibatch 1/1, validation error 31.333333 %
# epoch 189, minibatch 1/1, validation error 31.333333 %
# epoch 190, minibatch 1/1, validation error 31.333333 %
# epoch 191, minibatch 1/1, validation error 31.333333 %
# epoch 192, minibatch 1/1, validation error 31.333333 %
# epoch 193, minibatch 1/1, validation error 31.333333 %
# epoch 194, minibatch 1/1, validation error 31.333333 %
# epoch 195, minibatch 1/1, validation error 30.666667 %
# epoch 196, minibatch 1/1, validation error 30.666667 %
# epoch 197, minibatch 1/1, validation error 30.666667 %
# epoch 198, minibatch 1/1, validation error 30.666667 %
# epoch 199, minibatch 1/1, validation error 30.666667 %
# epoch 200, minibatch 1/1, validation error 30.666667 %
# epoch 201, minibatch 1/1, validation error 30.666667 %
# epoch 202, minibatch 1/1, validation error 30.666667 %
# epoch 203, minibatch 1/1, validation error 30.666667 %
# epoch 204, minibatch 1/1, validation error 30.666667 %
# epoch 205, minibatch 1/1, validation error 30.666667 %
# epoch 206, minibatch 1/1, validation error 30.666667 %
# epoch 207, minibatch 1/1, validation error 30.666667 %
# epoch 208, minibatch 1/1, validation error 30.000000 %
# epoch 209, minibatch 1/1, validation error 30.000000 %
# epoch 210, minibatch 1/1, validation error 30.000000 %
# epoch 211, minibatch 1/1, validation error 30.000000 %
# epoch 212, minibatch 1/1, validation error 30.000000 %
# epoch 213, minibatch 1/1, validation error 30.000000 %
# epoch 214, minibatch 1/1, validation error 30.000000 %
# epoch 215, minibatch 1/1, validation error 30.000000 %
# epoch 216, minibatch 1/1, validation error 30.000000 %
# epoch 217, minibatch 1/1, validation error 30.000000 %
# epoch 218, minibatch 1/1, validation error 30.000000 %
# epoch 219, minibatch 1/1, validation error 30.000000 %
# epoch 220, minibatch 1/1, validation error 29.333333 %
# epoch 221, minibatch 1/1, validation error 28.666667 %
# epoch 222, minibatch 1/1, validation error 28.666667 %
# epoch 223, minibatch 1/1, validation error 28.666667 %
# epoch 224, minibatch 1/1, validation error 28.666667 %
# epoch 225, minibatch 1/1, validation error 28.666667 %
# epoch 226, minibatch 1/1, validation error 28.666667 %
# epoch 227, minibatch 1/1, validation error 28.666667 %
# epoch 228, minibatch 1/1, validation error 28.666667 %
# epoch 229, minibatch 1/1, validation error 28.666667 %
# epoch 230, minibatch 1/1, validation error 28.666667 %
# epoch 231, minibatch 1/1, validation error 28.666667 %
# epoch 232, minibatch 1/1, validation error 28.000000 %
# epoch 233, minibatch 1/1, validation error 28.000000 %
# epoch 234, minibatch 1/1, validation error 28.000000 %
# epoch 235, minibatch 1/1, validation error 27.333333 %
# epoch 236, minibatch 1/1, validation error 27.333333 %
# epoch 237, minibatch 1/1, validation error 27.333333 %
# epoch 238, minibatch 1/1, validation error 27.333333 %
# epoch 239, minibatch 1/1, validation error 27.333333 %
# epoch 240, minibatch 1/1, validation error 27.333333 %
# epoch 241, minibatch 1/1, validation error 27.333333 %
# epoch 242, minibatch 1/1, validation error 26.666667 %
# epoch 243, minibatch 1/1, validation error 26.666667 %
# epoch 244, minibatch 1/1, validation error 26.666667 %
# epoch 245, minibatch 1/1, validation error 26.000000 %
# epoch 246, minibatch 1/1, validation error 26.000000 %
# epoch 247, minibatch 1/1, validation error 26.000000 %
# epoch 248, minibatch 1/1, validation error 26.000000 %
# epoch 249, minibatch 1/1, validation error 26.000000 %
# epoch 250, minibatch 1/1, validation error 26.000000 %
# epoch 251, minibatch 1/1, validation error 26.000000 %
# epoch 252, minibatch 1/1, validation error 26.000000 %
# epoch 253, minibatch 1/1, validation error 26.000000 %
# epoch 254, minibatch 1/1, validation error 26.000000 %
# epoch 255, minibatch 1/1, validation error 25.333333 %
# epoch 256, minibatch 1/1, validation error 25.333333 %
# epoch 257, minibatch 1/1, validation error 25.333333 %
# epoch 258, minibatch 1/1, validation error 25.333333 %
# epoch 259, minibatch 1/1, validation error 25.333333 %
# epoch 260, minibatch 1/1, validation error 25.333333 %
# epoch 261, minibatch 1/1, validation error 25.333333 %
# epoch 262, minibatch 1/1, validation error 25.333333 %
# epoch 263, minibatch 1/1, validation error 25.333333 %
# epoch 264, minibatch 1/1, validation error 25.333333 %
# epoch 265, minibatch 1/1, validation error 25.333333 %
# epoch 266, minibatch 1/1, validation error 25.333333 %
# epoch 267, minibatch 1/1, validation error 24.666667 %
# epoch 268, minibatch 1/1, validation error 24.666667 %
# epoch 269, minibatch 1/1, validation error 24.666667 %
# epoch 270, minibatch 1/1, validation error 24.666667 %
# epoch 271, minibatch 1/1, validation error 24.666667 %
# epoch 272, minibatch 1/1, validation error 24.666667 %
# epoch 273, minibatch 1/1, validation error 24.666667 %
# epoch 274, minibatch 1/1, validation error 24.666667 %
# epoch 275, minibatch 1/1, validation error 24.666667 %
# epoch 276, minibatch 1/1, validation error 24.666667 %
# epoch 277, minibatch 1/1, validation error 24.666667 %
# epoch 278, minibatch 1/1, validation error 24.666667 %
# epoch 279, minibatch 1/1, validation error 24.666667 %
# epoch 280, minibatch 1/1, validation error 24.666667 %
# epoch 281, minibatch 1/1, validation error 24.666667 %
# epoch 282, minibatch 1/1, validation error 24.666667 %
# epoch 283, minibatch 1/1, validation error 24.666667 %
# epoch 284, minibatch 1/1, validation error 24.666667 %
# epoch 285, minibatch 1/1, validation error 24.666667 %
# epoch 286, minibatch 1/1, validation error 24.666667 %
# epoch 287, minibatch 1/1, validation error 24.666667 %
# epoch 288, minibatch 1/1, validation error 24.666667 %
# epoch 289, minibatch 1/1, validation error 24.666667 %
# epoch 290, minibatch 1/1, validation error 24.000000 %
# epoch 291, minibatch 1/1, validation error 24.000000 %
# epoch 292, minibatch 1/1, validation error 24.000000 %
# epoch 293, minibatch 1/1, validation error 24.000000 %
# epoch 294, minibatch 1/1, validation error 24.000000 %
# epoch 295, minibatch 1/1, validation error 24.000000 %
# epoch 296, minibatch 1/1, validation error 24.000000 %
# epoch 297, minibatch 1/1, validation error 23.333333 %
# epoch 298, minibatch 1/1, validation error 23.333333 %
# epoch 299, minibatch 1/1, validation error 23.333333 %
# epoch 300, minibatch 1/1, validation error 23.333333 %
# epoch 301, minibatch 1/1, validation error 23.333333 %
# epoch 302, minibatch 1/1, validation error 22.666667 %
# epoch 303, minibatch 1/1, validation error 22.666667 %
# epoch 304, minibatch 1/1, validation error 22.666667 %
# epoch 305, minibatch 1/1, validation error 22.666667 %
# epoch 306, minibatch 1/1, validation error 22.666667 %
# epoch 307, minibatch 1/1, validation error 22.666667 %
# epoch 308, minibatch 1/1, validation error 22.666667 %
# epoch 309, minibatch 1/1, validation error 22.666667 %
# epoch 310, minibatch 1/1, validation error 22.666667 %
# epoch 311, minibatch 1/1, validation error 22.666667 %
# epoch 312, minibatch 1/1, validation error 22.666667 %
# epoch 313, minibatch 1/1, validation error 22.666667 %
# epoch 314, minibatch 1/1, validation error 22.666667 %
# epoch 315, minibatch 1/1, validation error 22.666667 %
# epoch 316, minibatch 1/1, validation error 22.000000 %
# epoch 317, minibatch 1/1, validation error 22.000000 %
# epoch 318, minibatch 1/1, validation error 22.000000 %
# epoch 319, minibatch 1/1, validation error 22.000000 %
# epoch 320, minibatch 1/1, validation error 22.000000 %
# epoch 321, minibatch 1/1, validation error 22.000000 %
# epoch 322, minibatch 1/1, validation error 22.000000 %
# epoch 323, minibatch 1/1, validation error 22.000000 %
# epoch 324, minibatch 1/1, validation error 22.000000 %
# epoch 325, minibatch 1/1, validation error 22.000000 %
# epoch 326, minibatch 1/1, validation error 22.000000 %
# epoch 327, minibatch 1/1, validation error 22.000000 %
# epoch 328, minibatch 1/1, validation error 21.333333 %
# epoch 329, minibatch 1/1, validation error 21.333333 %
# epoch 330, minibatch 1/1, validation error 21.333333 %
# epoch 331, minibatch 1/1, validation error 21.333333 %
# epoch 332, minibatch 1/1, validation error 21.333333 %
# epoch 333, minibatch 1/1, validation error 21.333333 %
# epoch 334, minibatch 1/1, validation error 21.333333 %
# epoch 335, minibatch 1/1, validation error 21.333333 %
# epoch 336, minibatch 1/1, validation error 21.333333 %
# epoch 337, minibatch 1/1, validation error 21.333333 %
# epoch 338, minibatch 1/1, validation error 21.333333 %
# epoch 339, minibatch 1/1, validation error 21.333333 %
# epoch 340, minibatch 1/1, validation error 21.333333 %
# epoch 341, minibatch 1/1, validation error 21.333333 %
# epoch 342, minibatch 1/1, validation error 21.333333 %
# epoch 343, minibatch 1/1, validation error 21.333333 %
# epoch 344, minibatch 1/1, validation error 21.333333 %
# epoch 345, minibatch 1/1, validation error 21.333333 %
# epoch 346, minibatch 1/1, validation error 21.333333 %
# epoch 347, minibatch 1/1, validation error 21.333333 %
# epoch 348, minibatch 1/1, validation error 21.333333 %
# epoch 349, minibatch 1/1, validation error 21.333333 %
# epoch 350, minibatch 1/1, validation error 21.333333 %
# epoch 351, minibatch 1/1, validation error 21.333333 %
# epoch 352, minibatch 1/1, validation error 21.333333 %
# epoch 353, minibatch 1/1, validation error 21.333333 %
# epoch 354, minibatch 1/1, validation error 21.333333 %
# epoch 355, minibatch 1/1, validation error 20.666667 %
# epoch 356, minibatch 1/1, validation error 20.666667 %
# epoch 357, minibatch 1/1, validation error 20.666667 %
# epoch 358, minibatch 1/1, validation error 20.666667 %
# epoch 359, minibatch 1/1, validation error 20.000000 %
# epoch 360, minibatch 1/1, validation error 20.000000 %
# epoch 361, minibatch 1/1, validation error 20.000000 %
# epoch 362, minibatch 1/1, validation error 20.000000 %
# epoch 363, minibatch 1/1, validation error 20.000000 %
# epoch 364, minibatch 1/1, validation error 20.000000 %
# epoch 365, minibatch 1/1, validation error 20.000000 %
# epoch 366, minibatch 1/1, validation error 20.000000 %
# epoch 367, minibatch 1/1, validation error 20.000000 %
# epoch 368, minibatch 1/1, validation error 20.000000 %
# epoch 369, minibatch 1/1, validation error 20.000000 %
# epoch 370, minibatch 1/1, validation error 20.000000 %
# epoch 371, minibatch 1/1, validation error 20.000000 %
# epoch 372, minibatch 1/1, validation error 20.000000 %
# epoch 373, minibatch 1/1, validation error 20.000000 %
# epoch 374, minibatch 1/1, validation error 20.000000 %
# epoch 375, minibatch 1/1, validation error 19.333333 %
# epoch 376, minibatch 1/1, validation error 19.333333 %
# epoch 377, minibatch 1/1, validation error 19.333333 %
# epoch 378, minibatch 1/1, validation error 19.333333 %
# epoch 379, minibatch 1/1, validation error 19.333333 %
# epoch 380, minibatch 1/1, validation error 19.333333 %
# epoch 381, minibatch 1/1, validation error 19.333333 %
# epoch 382, minibatch 1/1, validation error 19.333333 %
# epoch 383, minibatch 1/1, validation error 19.333333 %
# epoch 384, minibatch 1/1, validation error 18.666667 %
# epoch 385, minibatch 1/1, validation error 18.666667 %
# epoch 386, minibatch 1/1, validation error 18.666667 %
# epoch 387, minibatch 1/1, validation error 18.666667 %
# epoch 388, minibatch 1/1, validation error 18.666667 %
# epoch 389, minibatch 1/1, validation error 18.000000 %
# epoch 390, minibatch 1/1, validation error 18.000000 %
# epoch 391, minibatch 1/1, validation error 18.000000 %
# epoch 392, minibatch 1/1, validation error 18.000000 %
# epoch 393, minibatch 1/1, validation error 18.000000 %
# epoch 394, minibatch 1/1, validation error 18.000000 %
# epoch 395, minibatch 1/1, validation error 18.000000 %
# epoch 396, minibatch 1/1, validation error 18.000000 %
# epoch 397, minibatch 1/1, validation error 18.000000 %
# epoch 398, minibatch 1/1, validation error 18.000000 %
# epoch 399, minibatch 1/1, validation error 18.000000 %
# epoch 400, minibatch 1/1, validation error 18.000000 %
# epoch 401, minibatch 1/1, validation error 18.000000 %
# epoch 402, minibatch 1/1, validation error 18.000000 %
# epoch 403, minibatch 1/1, validation error 18.000000 %
# epoch 404, minibatch 1/1, validation error 18.000000 %
# epoch 405, minibatch 1/1, validation error 18.000000 %
# epoch 406, minibatch 1/1, validation error 18.000000 %
# epoch 407, minibatch 1/1, validation error 18.000000 %
# epoch 408, minibatch 1/1, validation error 18.000000 %
# epoch 409, minibatch 1/1, validation error 18.000000 %
# epoch 410, minibatch 1/1, validation error 17.333333 %
# epoch 411, minibatch 1/1, validation error 17.333333 %
# epoch 412, minibatch 1/1, validation error 17.333333 %
# epoch 413, minibatch 1/1, validation error 17.333333 %
# epoch 414, minibatch 1/1, validation error 17.333333 %
# epoch 415, minibatch 1/1, validation error 17.333333 %
# epoch 416, minibatch 1/1, validation error 17.333333 %
# epoch 417, minibatch 1/1, validation error 17.333333 %
# epoch 418, minibatch 1/1, validation error 16.666667 %
# epoch 419, minibatch 1/1, validation error 16.666667 %
# epoch 420, minibatch 1/1, validation error 16.666667 %
# epoch 421, minibatch 1/1, validation error 16.000000 %
# epoch 422, minibatch 1/1, validation error 16.000000 %
# epoch 423, minibatch 1/1, validation error 16.000000 %
# epoch 424, minibatch 1/1, validation error 16.000000 %
# epoch 425, minibatch 1/1, validation error 16.000000 %
# epoch 426, minibatch 1/1, validation error 16.000000 %
# epoch 427, minibatch 1/1, validation error 16.000000 %
# epoch 428, minibatch 1/1, validation error 16.000000 %
# epoch 429, minibatch 1/1, validation error 16.000000 %
# epoch 430, minibatch 1/1, validation error 16.000000 %
# epoch 431, minibatch 1/1, validation error 16.000000 %
# epoch 432, minibatch 1/1, validation error 16.000000 %
# epoch 433, minibatch 1/1, validation error 16.000000 %
# epoch 434, minibatch 1/1, validation error 16.000000 %
# epoch 435, minibatch 1/1, validation error 16.000000 %
# epoch 436, minibatch 1/1, validation error 16.000000 %
# epoch 437, minibatch 1/1, validation error 16.000000 %
# epoch 438, minibatch 1/1, validation error 16.000000 %
# epoch 439, minibatch 1/1, validation error 16.000000 %
# epoch 440, minibatch 1/1, validation error 16.000000 %
# epoch 441, minibatch 1/1, validation error 16.000000 %
# epoch 442, minibatch 1/1, validation error 16.000000 %
# epoch 443, minibatch 1/1, validation error 16.000000 %
# epoch 444, minibatch 1/1, validation error 16.000000 %
# epoch 445, minibatch 1/1, validation error 16.000000 %
# epoch 446, minibatch 1/1, validation error 16.000000 %
# epoch 447, minibatch 1/1, validation error 15.333333 %
# epoch 448, minibatch 1/1, validation error 15.333333 %
# epoch 449, minibatch 1/1, validation error 15.333333 %
# epoch 450, minibatch 1/1, validation error 15.333333 %
# epoch 451, minibatch 1/1, validation error 15.333333 %
# epoch 452, minibatch 1/1, validation error 15.333333 %
# epoch 453, minibatch 1/1, validation error 15.333333 %
# epoch 454, minibatch 1/1, validation error 15.333333 %
# epoch 455, minibatch 1/1, validation error 15.333333 %
# epoch 456, minibatch 1/1, validation error 15.333333 %
# epoch 457, minibatch 1/1, validation error 14.666667 %
# epoch 458, minibatch 1/1, validation error 14.666667 %
# epoch 459, minibatch 1/1, validation error 14.666667 %
# epoch 460, minibatch 1/1, validation error 14.666667 %
# epoch 461, minibatch 1/1, validation error 14.666667 %
# epoch 462, minibatch 1/1, validation error 14.666667 %
# epoch 463, minibatch 1/1, validation error 14.666667 %
# epoch 464, minibatch 1/1, validation error 14.666667 %
# epoch 465, minibatch 1/1, validation error 14.666667 %
# epoch 466, minibatch 1/1, validation error 14.666667 %
# epoch 467, minibatch 1/1, validation error 14.666667 %
# epoch 468, minibatch 1/1, validation error 14.666667 %
# epoch 469, minibatch 1/1, validation error 14.666667 %
# epoch 470, minibatch 1/1, validation error 14.666667 %
# epoch 471, minibatch 1/1, validation error 14.666667 %
# epoch 472, minibatch 1/1, validation error 14.666667 %
# epoch 473, minibatch 1/1, validation error 14.666667 %
# epoch 474, minibatch 1/1, validation error 14.666667 %
# epoch 475, minibatch 1/1, validation error 14.666667 %
# epoch 476, minibatch 1/1, validation error 14.666667 %
# epoch 477, minibatch 1/1, validation error 14.666667 %
# epoch 478, minibatch 1/1, validation error 14.666667 %
# epoch 479, minibatch 1/1, validation error 14.666667 %
# epoch 480, minibatch 1/1, validation error 14.666667 %
# epoch 481, minibatch 1/1, validation error 14.666667 %
# epoch 482, minibatch 1/1, validation error 14.666667 %
# epoch 483, minibatch 1/1, validation error 14.666667 %
# epoch 484, minibatch 1/1, validation error 14.666667 %
# epoch 485, minibatch 1/1, validation error 14.666667 %
# epoch 486, minibatch 1/1, validation error 14.666667 %
# epoch 487, minibatch 1/1, validation error 14.666667 %
# epoch 488, minibatch 1/1, validation error 14.666667 %
# epoch 489, minibatch 1/1, validation error 14.666667 %
# epoch 490, minibatch 1/1, validation error 14.666667 %
# epoch 491, minibatch 1/1, validation error 14.666667 %
# epoch 492, minibatch 1/1, validation error 14.666667 %
# epoch 493, minibatch 1/1, validation error 14.666667 %
# epoch 494, minibatch 1/1, validation error 13.333333 %
# epoch 495, minibatch 1/1, validation error 13.333333 %
# epoch 496, minibatch 1/1, validation error 13.333333 %
# epoch 497, minibatch 1/1, validation error 13.333333 %
# epoch 498, minibatch 1/1, validation error 13.333333 %
# epoch 499, minibatch 1/1, validation error 13.333333 %
# epoch 500, minibatch 1/1, validation error 13.333333 %
# epoch 501, minibatch 1/1, validation error 13.333333 %
# epoch 502, minibatch 1/1, validation error 13.333333 %
# epoch 503, minibatch 1/1, validation error 13.333333 %
# epoch 504, minibatch 1/1, validation error 13.333333 %
# epoch 505, minibatch 1/1, validation error 13.333333 %
# epoch 506, minibatch 1/1, validation error 13.333333 %
# epoch 507, minibatch 1/1, validation error 13.333333 %
# epoch 508, minibatch 1/1, validation error 13.333333 %
# epoch 509, minibatch 1/1, validation error 13.333333 %
# epoch 510, minibatch 1/1, validation error 13.333333 %
# epoch 511, minibatch 1/1, validation error 13.333333 %
# epoch 512, minibatch 1/1, validation error 13.333333 %
# epoch 513, minibatch 1/1, validation error 13.333333 %
# epoch 514, minibatch 1/1, validation error 13.333333 %
# epoch 515, minibatch 1/1, validation error 13.333333 %
# epoch 516, minibatch 1/1, validation error 13.333333 %
# epoch 517, minibatch 1/1, validation error 13.333333 %
# epoch 518, minibatch 1/1, validation error 13.333333 %
# epoch 519, minibatch 1/1, validation error 13.333333 %
# epoch 520, minibatch 1/1, validation error 13.333333 %
# epoch 521, minibatch 1/1, validation error 13.333333 %
# epoch 522, minibatch 1/1, validation error 13.333333 %
# epoch 523, minibatch 1/1, validation error 13.333333 %
# epoch 524, minibatch 1/1, validation error 13.333333 %
# epoch 525, minibatch 1/1, validation error 13.333333 %
# epoch 526, minibatch 1/1, validation error 13.333333 %
# epoch 527, minibatch 1/1, validation error 13.333333 %
# epoch 528, minibatch 1/1, validation error 13.333333 %
# epoch 529, minibatch 1/1, validation error 13.333333 %
# epoch 530, minibatch 1/1, validation error 13.333333 %
# epoch 531, minibatch 1/1, validation error 13.333333 %
# epoch 532, minibatch 1/1, validation error 13.333333 %
# epoch 533, minibatch 1/1, validation error 13.333333 %
# epoch 534, minibatch 1/1, validation error 13.333333 %
# epoch 535, minibatch 1/1, validation error 13.333333 %
# epoch 536, minibatch 1/1, validation error 13.333333 %
# epoch 537, minibatch 1/1, validation error 13.333333 %
# epoch 538, minibatch 1/1, validation error 13.333333 %
# epoch 539, minibatch 1/1, validation error 13.333333 %
# epoch 540, minibatch 1/1, validation error 13.333333 %
# epoch 541, minibatch 1/1, validation error 13.333333 %
# epoch 542, minibatch 1/1, validation error 13.333333 %
# epoch 543, minibatch 1/1, validation error 13.333333 %
# epoch 544, minibatch 1/1, validation error 13.333333 %
# epoch 545, minibatch 1/1, validation error 13.333333 %
# epoch 546, minibatch 1/1, validation error 13.333333 %
# epoch 547, minibatch 1/1, validation error 13.333333 %
# epoch 548, minibatch 1/1, validation error 12.666667 %
# epoch 549, minibatch 1/1, validation error 12.666667 %
# epoch 550, minibatch 1/1, validation error 12.666667 %
# epoch 551, minibatch 1/1, validation error 12.000000 %
# epoch 552, minibatch 1/1, validation error 12.000000 %
# epoch 553, minibatch 1/1, validation error 12.000000 %
# epoch 554, minibatch 1/1, validation error 12.000000 %
# epoch 555, minibatch 1/1, validation error 12.000000 %
# epoch 556, minibatch 1/1, validation error 12.000000 %
# epoch 557, minibatch 1/1, validation error 12.000000 %
# epoch 558, minibatch 1/1, validation error 12.000000 %
# epoch 559, minibatch 1/1, validation error 12.000000 %
# epoch 560, minibatch 1/1, validation error 12.000000 %
# epoch 561, minibatch 1/1, validation error 12.000000 %
# epoch 562, minibatch 1/1, validation error 12.000000 %
# epoch 563, minibatch 1/1, validation error 12.000000 %
# epoch 564, minibatch 1/1, validation error 12.000000 %
# epoch 565, minibatch 1/1, validation error 12.000000 %
# epoch 566, minibatch 1/1, validation error 12.000000 %
# epoch 567, minibatch 1/1, validation error 12.000000 %
# epoch 568, minibatch 1/1, validation error 12.000000 %
# epoch 569, minibatch 1/1, validation error 12.000000 %
# epoch 570, minibatch 1/1, validation error 12.000000 %
# epoch 571, minibatch 1/1, validation error 12.000000 %
# epoch 572, minibatch 1/1, validation error 12.000000 %
# epoch 573, minibatch 1/1, validation error 12.000000 %
# epoch 574, minibatch 1/1, validation error 12.000000 %
# epoch 575, minibatch 1/1, validation error 12.000000 %
# epoch 576, minibatch 1/1, validation error 12.000000 %
# epoch 577, minibatch 1/1, validation error 12.000000 %
# epoch 578, minibatch 1/1, validation error 12.000000 %
# epoch 579, minibatch 1/1, validation error 12.000000 %
# epoch 580, minibatch 1/1, validation error 12.000000 %
# epoch 581, minibatch 1/1, validation error 12.000000 %
# epoch 582, minibatch 1/1, validation error 12.000000 %
# epoch 583, minibatch 1/1, validation error 12.000000 %
# epoch 584, minibatch 1/1, validation error 12.000000 %
# epoch 585, minibatch 1/1, validation error 12.000000 %
# epoch 586, minibatch 1/1, validation error 12.000000 %
# epoch 587, minibatch 1/1, validation error 12.000000 %
# epoch 588, minibatch 1/1, validation error 12.000000 %
# epoch 589, minibatch 1/1, validation error 12.000000 %
# epoch 590, minibatch 1/1, validation error 12.000000 %
# epoch 591, minibatch 1/1, validation error 12.000000 %
# epoch 592, minibatch 1/1, validation error 12.000000 %
# epoch 593, minibatch 1/1, validation error 12.000000 %
# epoch 594, minibatch 1/1, validation error 12.000000 %
# epoch 595, minibatch 1/1, validation error 12.000000 %
# epoch 596, minibatch 1/1, validation error 12.000000 %
# epoch 597, minibatch 1/1, validation error 12.000000 %
# epoch 598, minibatch 1/1, validation error 12.000000 %
# epoch 599, minibatch 1/1, validation error 12.000000 %
# epoch 600, minibatch 1/1, validation error 12.000000 %
# epoch 601, minibatch 1/1, validation error 12.000000 %
# epoch 602, minibatch 1/1, validation error 12.000000 %
# epoch 603, minibatch 1/1, validation error 12.000000 %
# epoch 604, minibatch 1/1, validation error 12.000000 %
# epoch 605, minibatch 1/1, validation error 12.000000 %
# epoch 606, minibatch 1/1, validation error 12.000000 %
# epoch 607, minibatch 1/1, validation error 12.000000 %
# epoch 608, minibatch 1/1, validation error 12.000000 %
# epoch 609, minibatch 1/1, validation error 12.000000 %
# epoch 610, minibatch 1/1, validation error 12.000000 %
# epoch 611, minibatch 1/1, validation error 12.000000 %
# epoch 612, minibatch 1/1, validation error 12.000000 %
# epoch 613, minibatch 1/1, validation error 12.000000 %
# epoch 614, minibatch 1/1, validation error 12.000000 %
# epoch 615, minibatch 1/1, validation error 12.000000 %
# epoch 616, minibatch 1/1, validation error 12.000000 %
# epoch 617, minibatch 1/1, validation error 12.000000 %
# epoch 618, minibatch 1/1, validation error 10.666667 %
# epoch 619, minibatch 1/1, validation error 10.666667 %
# epoch 620, minibatch 1/1, validation error 10.666667 %
# epoch 621, minibatch 1/1, validation error 10.666667 %
# epoch 622, minibatch 1/1, validation error 10.666667 %
# epoch 623, minibatch 1/1, validation error 10.666667 %
# epoch 624, minibatch 1/1, validation error 10.666667 %
# epoch 625, minibatch 1/1, validation error 10.666667 %
# epoch 626, minibatch 1/1, validation error 10.666667 %
# epoch 627, minibatch 1/1, validation error 10.666667 %
# epoch 628, minibatch 1/1, validation error 10.666667 %
# epoch 629, minibatch 1/1, validation error 10.666667 %
# epoch 630, minibatch 1/1, validation error 10.666667 %
# epoch 631, minibatch 1/1, validation error 10.666667 %
# epoch 632, minibatch 1/1, validation error 10.666667 %
# epoch 633, minibatch 1/1, validation error 10.666667 %
# epoch 634, minibatch 1/1, validation error 10.666667 %
# epoch 635, minibatch 1/1, validation error 10.666667 %
# epoch 636, minibatch 1/1, validation error 10.666667 %
# epoch 637, minibatch 1/1, validation error 10.666667 %
# epoch 638, minibatch 1/1, validation error 10.666667 %
# epoch 639, minibatch 1/1, validation error 10.666667 %
# epoch 640, minibatch 1/1, validation error 10.666667 %
# epoch 641, minibatch 1/1, validation error 10.666667 %
# epoch 642, minibatch 1/1, validation error 10.666667 %
# epoch 643, minibatch 1/1, validation error 10.666667 %
# epoch 644, minibatch 1/1, validation error 10.666667 %
# epoch 645, minibatch 1/1, validation error 10.666667 %
# epoch 646, minibatch 1/1, validation error 10.666667 %
# epoch 647, minibatch 1/1, validation error 10.666667 %
# epoch 648, minibatch 1/1, validation error 10.666667 %
# epoch 649, minibatch 1/1, validation error 10.666667 %
# epoch 650, minibatch 1/1, validation error 10.666667 %
# epoch 651, minibatch 1/1, validation error 10.666667 %
# epoch 652, minibatch 1/1, validation error 10.666667 %
# epoch 653, minibatch 1/1, validation error 10.666667 %
# epoch 654, minibatch 1/1, validation error 10.666667 %
# epoch 655, minibatch 1/1, validation error 10.666667 %
# epoch 656, minibatch 1/1, validation error 10.666667 %
# epoch 657, minibatch 1/1, validation error 10.666667 %
# epoch 658, minibatch 1/1, validation error 10.666667 %
# epoch 659, minibatch 1/1, validation error 10.666667 %
# epoch 660, minibatch 1/1, validation error 10.666667 %
# epoch 661, minibatch 1/1, validation error 10.666667 %
# epoch 662, minibatch 1/1, validation error 10.666667 %
# epoch 663, minibatch 1/1, validation error 10.666667 %
# epoch 664, minibatch 1/1, validation error 10.666667 %
# epoch 665, minibatch 1/1, validation error 10.666667 %
# epoch 666, minibatch 1/1, validation error 10.666667 %
# epoch 667, minibatch 1/1, validation error 10.666667 %
# epoch 668, minibatch 1/1, validation error 10.666667 %
# epoch 669, minibatch 1/1, validation error 10.666667 %
# epoch 670, minibatch 1/1, validation error 10.666667 %
# epoch 671, minibatch 1/1, validation error 10.666667 %
# epoch 672, minibatch 1/1, validation error 10.666667 %
# epoch 673, minibatch 1/1, validation error 10.666667 %
# epoch 674, minibatch 1/1, validation error 10.666667 %
# epoch 675, minibatch 1/1, validation error 10.666667 %
# epoch 676, minibatch 1/1, validation error 10.666667 %
# epoch 677, minibatch 1/1, validation error 10.666667 %
# epoch 678, minibatch 1/1, validation error 10.666667 %
# epoch 679, minibatch 1/1, validation error 10.666667 %
# epoch 680, minibatch 1/1, validation error 10.666667 %
# epoch 681, minibatch 1/1, validation error 10.666667 %
# epoch 682, minibatch 1/1, validation error 10.666667 %
# epoch 683, minibatch 1/1, validation error 10.666667 %
# epoch 684, minibatch 1/1, validation error 10.666667 %
# epoch 685, minibatch 1/1, validation error 10.666667 %
# epoch 686, minibatch 1/1, validation error 10.666667 %
# epoch 687, minibatch 1/1, validation error 10.666667 %
# epoch 688, minibatch 1/1, validation error 10.666667 %
# epoch 689, minibatch 1/1, validation error 10.666667 %
# epoch 690, minibatch 1/1, validation error 10.666667 %
# epoch 691, minibatch 1/1, validation error 10.666667 %
# epoch 692, minibatch 1/1, validation error 10.666667 %
# epoch 693, minibatch 1/1, validation error 10.666667 %
# epoch 694, minibatch 1/1, validation error 10.666667 %
# epoch 695, minibatch 1/1, validation error 10.666667 %
# epoch 696, minibatch 1/1, validation error 10.666667 %
# epoch 697, minibatch 1/1, validation error 10.666667 %
# epoch 698, minibatch 1/1, validation error 10.666667 %
# epoch 699, minibatch 1/1, validation error 10.666667 %
# epoch 700, minibatch 1/1, validation error 10.666667 %
# epoch 701, minibatch 1/1, validation error 10.666667 %
# epoch 702, minibatch 1/1, validation error 10.666667 %
# epoch 703, minibatch 1/1, validation error 10.666667 %
# epoch 704, minibatch 1/1, validation error 10.666667 %
# epoch 705, minibatch 1/1, validation error 10.666667 %
# epoch 706, minibatch 1/1, validation error 10.666667 %
# epoch 707, minibatch 1/1, validation error 10.666667 %
# epoch 708, minibatch 1/1, validation error 10.666667 %
# epoch 709, minibatch 1/1, validation error 10.666667 %
# epoch 710, minibatch 1/1, validation error 10.666667 %
# epoch 711, minibatch 1/1, validation error 10.666667 %
# epoch 712, minibatch 1/1, validation error 10.666667 %
# epoch 713, minibatch 1/1, validation error 10.666667 %
# epoch 714, minibatch 1/1, validation error 10.666667 %
# epoch 715, minibatch 1/1, validation error 10.666667 %
# epoch 716, minibatch 1/1, validation error 10.666667 %
# epoch 717, minibatch 1/1, validation error 10.666667 %
# epoch 718, minibatch 1/1, validation error 10.666667 %
# epoch 719, minibatch 1/1, validation error 10.666667 %
# epoch 720, minibatch 1/1, validation error 10.666667 %
# epoch 721, minibatch 1/1, validation error 10.666667 %
# epoch 722, minibatch 1/1, validation error 10.000000 %
# epoch 723, minibatch 1/1, validation error 10.000000 %
# epoch 724, minibatch 1/1, validation error 10.000000 %
# epoch 725, minibatch 1/1, validation error 10.000000 %
# epoch 726, minibatch 1/1, validation error 10.000000 %
# epoch 727, minibatch 1/1, validation error 10.000000 %
# epoch 728, minibatch 1/1, validation error 10.000000 %
# epoch 729, minibatch 1/1, validation error 10.000000 %
# epoch 730, minibatch 1/1, validation error 10.000000 %
# epoch 731, minibatch 1/1, validation error 10.000000 %
# epoch 732, minibatch 1/1, validation error 10.000000 %
# epoch 733, minibatch 1/1, validation error 10.000000 %
# epoch 734, minibatch 1/1, validation error 10.000000 %
# epoch 735, minibatch 1/1, validation error 10.000000 %
# epoch 736, minibatch 1/1, validation error 10.000000 %
# epoch 737, minibatch 1/1, validation error 10.000000 %
# epoch 738, minibatch 1/1, validation error 10.000000 %
# epoch 739, minibatch 1/1, validation error 10.000000 %
# epoch 740, minibatch 1/1, validation error 10.000000 %
# epoch 741, minibatch 1/1, validation error 10.000000 %
# epoch 742, minibatch 1/1, validation error 10.000000 %
# epoch 743, minibatch 1/1, validation error 10.000000 %
# epoch 744, minibatch 1/1, validation error 10.000000 %
# epoch 745, minibatch 1/1, validation error 10.000000 %
# epoch 746, minibatch 1/1, validation error 10.000000 %
# epoch 747, minibatch 1/1, validation error 10.000000 %
# epoch 748, minibatch 1/1, validation error 10.000000 %
# epoch 749, minibatch 1/1, validation error 10.000000 %
# epoch 750, minibatch 1/1, validation error 10.000000 %
# epoch 751, minibatch 1/1, validation error 10.000000 %
# epoch 752, minibatch 1/1, validation error 10.000000 %
# epoch 753, minibatch 1/1, validation error 10.000000 %
# epoch 754, minibatch 1/1, validation error 10.000000 %
# epoch 755, minibatch 1/1, validation error 10.000000 %
# epoch 756, minibatch 1/1, validation error 10.000000 %
# epoch 757, minibatch 1/1, validation error 10.000000 %
# epoch 758, minibatch 1/1, validation error 10.000000 %
# epoch 759, minibatch 1/1, validation error 10.000000 %
# epoch 760, minibatch 1/1, validation error 10.000000 %
# epoch 761, minibatch 1/1, validation error 10.000000 %
# epoch 762, minibatch 1/1, validation error 10.000000 %
# epoch 763, minibatch 1/1, validation error 10.000000 %
# epoch 764, minibatch 1/1, validation error 10.000000 %
# epoch 765, minibatch 1/1, validation error 10.000000 %
# epoch 766, minibatch 1/1, validation error 10.000000 %
# epoch 767, minibatch 1/1, validation error 10.000000 %
# epoch 768, minibatch 1/1, validation error 10.000000 %
# epoch 769, minibatch 1/1, validation error 10.000000 %
# epoch 770, minibatch 1/1, validation error 10.000000 %
# epoch 771, minibatch 1/1, validation error 10.000000 %
# epoch 772, minibatch 1/1, validation error 10.000000 %
# epoch 773, minibatch 1/1, validation error 10.000000 %
# epoch 774, minibatch 1/1, validation error 10.000000 %
# epoch 775, minibatch 1/1, validation error 10.000000 %
# epoch 776, minibatch 1/1, validation error 10.000000 %
# epoch 777, minibatch 1/1, validation error 10.000000 %
# epoch 778, minibatch 1/1, validation error 10.000000 %
# epoch 779, minibatch 1/1, validation error 10.000000 %
# epoch 780, minibatch 1/1, validation error 10.000000 %
# epoch 781, minibatch 1/1, validation error 10.000000 %
# epoch 782, minibatch 1/1, validation error 10.000000 %
# epoch 783, minibatch 1/1, validation error 10.000000 %
# epoch 784, minibatch 1/1, validation error 10.000000 %
# epoch 785, minibatch 1/1, validation error 10.000000 %
# epoch 786, minibatch 1/1, validation error 10.000000 %
# epoch 787, minibatch 1/1, validation error 10.000000 %
# epoch 788, minibatch 1/1, validation error 10.000000 %
# epoch 789, minibatch 1/1, validation error 10.000000 %
# epoch 790, minibatch 1/1, validation error 10.000000 %
# epoch 791, minibatch 1/1, validation error 10.000000 %
# epoch 792, minibatch 1/1, validation error 10.000000 %
# epoch 793, minibatch 1/1, validation error 10.000000 %
# epoch 794, minibatch 1/1, validation error 10.000000 %
# epoch 795, minibatch 1/1, validation error 10.000000 %
# epoch 796, minibatch 1/1, validation error 10.000000 %
# epoch 797, minibatch 1/1, validation error 10.000000 %
# epoch 798, minibatch 1/1, validation error 10.000000 %
# epoch 799, minibatch 1/1, validation error 10.000000 %
# epoch 800, minibatch 1/1, validation error 10.000000 %
# epoch 801, minibatch 1/1, validation error 10.000000 %
# epoch 802, minibatch 1/1, validation error 10.000000 %
# epoch 803, minibatch 1/1, validation error 10.000000 %
# epoch 804, minibatch 1/1, validation error 10.000000 %
# epoch 805, minibatch 1/1, validation error 10.000000 %
# epoch 806, minibatch 1/1, validation error 10.000000 %
# epoch 807, minibatch 1/1, validation error 10.000000 %
# epoch 808, minibatch 1/1, validation error 10.000000 %
# epoch 809, minibatch 1/1, validation error 10.000000 %
# epoch 810, minibatch 1/1, validation error 10.000000 %
# epoch 811, minibatch 1/1, validation error 10.000000 %
# epoch 812, minibatch 1/1, validation error 10.000000 %
# epoch 813, minibatch 1/1, validation error 10.000000 %
# epoch 814, minibatch 1/1, validation error 9.333333 %
# epoch 815, minibatch 1/1, validation error 9.333333 %
# epoch 816, minibatch 1/1, validation error 9.333333 %
# epoch 817, minibatch 1/1, validation error 9.333333 %
# epoch 818, minibatch 1/1, validation error 9.333333 %
# epoch 819, minibatch 1/1, validation error 9.333333 %
# epoch 820, minibatch 1/1, validation error 9.333333 %
# epoch 821, minibatch 1/1, validation error 9.333333 %
# epoch 822, minibatch 1/1, validation error 9.333333 %
# epoch 823, minibatch 1/1, validation error 9.333333 %
# epoch 824, minibatch 1/1, validation error 9.333333 %
# epoch 825, minibatch 1/1, validation error 9.333333 %
# epoch 826, minibatch 1/1, validation error 9.333333 %
# epoch 827, minibatch 1/1, validation error 9.333333 %
# epoch 828, minibatch 1/1, validation error 9.333333 %
# epoch 829, minibatch 1/1, validation error 9.333333 %
# epoch 830, minibatch 1/1, validation error 9.333333 %
# epoch 831, minibatch 1/1, validation error 9.333333 %
# epoch 832, minibatch 1/1, validation error 9.333333 %
# epoch 833, minibatch 1/1, validation error 9.333333 %
# epoch 834, minibatch 1/1, validation error 9.333333 %
# epoch 835, minibatch 1/1, validation error 9.333333 %
# epoch 836, minibatch 1/1, validation error 9.333333 %
# epoch 837, minibatch 1/1, validation error 9.333333 %
# epoch 838, minibatch 1/1, validation error 9.333333 %
# epoch 839, minibatch 1/1, validation error 9.333333 %
# epoch 840, minibatch 1/1, validation error 9.333333 %
# epoch 841, minibatch 1/1, validation error 9.333333 %
# epoch 842, minibatch 1/1, validation error 9.333333 %
# epoch 843, minibatch 1/1, validation error 9.333333 %
# epoch 844, minibatch 1/1, validation error 9.333333 %
# epoch 845, minibatch 1/1, validation error 10.000000 %
# epoch 846, minibatch 1/1, validation error 10.000000 %
# epoch 847, minibatch 1/1, validation error 10.000000 %
# epoch 848, minibatch 1/1, validation error 10.000000 %
# epoch 849, minibatch 1/1, validation error 10.000000 %
# epoch 850, minibatch 1/1, validation error 10.000000 %
# epoch 851, minibatch 1/1, validation error 10.000000 %
# epoch 852, minibatch 1/1, validation error 10.000000 %
# epoch 853, minibatch 1/1, validation error 10.000000 %
# epoch 854, minibatch 1/1, validation error 10.000000 %
# epoch 855, minibatch 1/1, validation error 10.000000 %
# epoch 856, minibatch 1/1, validation error 10.000000 %
# epoch 857, minibatch 1/1, validation error 10.000000 %
# epoch 858, minibatch 1/1, validation error 10.000000 %
# epoch 859, minibatch 1/1, validation error 10.000000 %
# epoch 860, minibatch 1/1, validation error 10.000000 %
# epoch 861, minibatch 1/1, validation error 10.000000 %
# epoch 862, minibatch 1/1, validation error 10.000000 %
# epoch 863, minibatch 1/1, validation error 10.000000 %
# epoch 864, minibatch 1/1, validation error 10.000000 %
# epoch 865, minibatch 1/1, validation error 10.000000 %
# epoch 866, minibatch 1/1, validation error 10.000000 %
# epoch 867, minibatch 1/1, validation error 10.000000 %
# epoch 868, minibatch 1/1, validation error 10.000000 %
# epoch 869, minibatch 1/1, validation error 10.000000 %
# epoch 870, minibatch 1/1, validation error 10.000000 %
# epoch 871, minibatch 1/1, validation error 10.000000 %
# epoch 872, minibatch 1/1, validation error 10.000000 %
# epoch 873, minibatch 1/1, validation error 10.000000 %
# epoch 874, minibatch 1/1, validation error 10.000000 %
# epoch 875, minibatch 1/1, validation error 10.000000 %
# epoch 876, minibatch 1/1, validation error 10.000000 %
# epoch 877, minibatch 1/1, validation error 10.000000 %
# epoch 878, minibatch 1/1, validation error 10.000000 %
# epoch 879, minibatch 1/1, validation error 10.000000 %
# epoch 880, minibatch 1/1, validation error 10.000000 %
# epoch 881, minibatch 1/1, validation error 10.000000 %
# epoch 882, minibatch 1/1, validation error 10.000000 %
# epoch 883, minibatch 1/1, validation error 10.000000 %
# epoch 884, minibatch 1/1, validation error 10.000000 %
# epoch 885, minibatch 1/1, validation error 10.000000 %
# epoch 886, minibatch 1/1, validation error 10.000000 %
# epoch 887, minibatch 1/1, validation error 10.000000 %
# epoch 888, minibatch 1/1, validation error 10.000000 %
# epoch 889, minibatch 1/1, validation error 9.333333 %
# epoch 890, minibatch 1/1, validation error 9.333333 %
# epoch 891, minibatch 1/1, validation error 9.333333 %
# epoch 892, minibatch 1/1, validation error 9.333333 %
# epoch 893, minibatch 1/1, validation error 9.333333 %
# epoch 894, minibatch 1/1, validation error 9.333333 %
# epoch 895, minibatch 1/1, validation error 9.333333 %
# epoch 896, minibatch 1/1, validation error 9.333333 %
# epoch 897, minibatch 1/1, validation error 9.333333 %
# epoch 898, minibatch 1/1, validation error 9.333333 %
# epoch 899, minibatch 1/1, validation error 9.333333 %
# epoch 900, minibatch 1/1, validation error 9.333333 %
# epoch 901, minibatch 1/1, validation error 9.333333 %
# epoch 902, minibatch 1/1, validation error 9.333333 %
# epoch 903, minibatch 1/1, validation error 9.333333 %
# epoch 904, minibatch 1/1, validation error 9.333333 %
# epoch 905, minibatch 1/1, validation error 9.333333 %
# epoch 906, minibatch 1/1, validation error 9.333333 %
# epoch 907, minibatch 1/1, validation error 9.333333 %
# epoch 908, minibatch 1/1, validation error 9.333333 %
# epoch 909, minibatch 1/1, validation error 9.333333 %
# epoch 910, minibatch 1/1, validation error 9.333333 %
# epoch 911, minibatch 1/1, validation error 9.333333 %
# epoch 912, minibatch 1/1, validation error 9.333333 %
# epoch 913, minibatch 1/1, validation error 9.333333 %
# epoch 914, minibatch 1/1, validation error 9.333333 %
# epoch 915, minibatch 1/1, validation error 9.333333 %
# epoch 916, minibatch 1/1, validation error 8.000000 %
# epoch 917, minibatch 1/1, validation error 8.000000 %
# epoch 918, minibatch 1/1, validation error 8.000000 %
# epoch 919, minibatch 1/1, validation error 8.000000 %
# epoch 920, minibatch 1/1, validation error 8.000000 %
# epoch 921, minibatch 1/1, validation error 8.000000 %
# epoch 922, minibatch 1/1, validation error 8.000000 %
# epoch 923, minibatch 1/1, validation error 8.000000 %
# epoch 924, minibatch 1/1, validation error 8.000000 %
# epoch 925, minibatch 1/1, validation error 8.000000 %
# epoch 926, minibatch 1/1, validation error 8.000000 %
# epoch 927, minibatch 1/1, validation error 8.000000 %
# epoch 928, minibatch 1/1, validation error 8.000000 %
# epoch 929, minibatch 1/1, validation error 8.000000 %
# epoch 930, minibatch 1/1, validation error 8.000000 %
# epoch 931, minibatch 1/1, validation error 8.000000 %
# epoch 932, minibatch 1/1, validation error 8.000000 %
# epoch 933, minibatch 1/1, validation error 8.000000 %
# epoch 934, minibatch 1/1, validation error 8.000000 %
# epoch 935, minibatch 1/1, validation error 8.000000 %
# epoch 936, minibatch 1/1, validation error 8.000000 %
# epoch 937, minibatch 1/1, validation error 8.000000 %
# epoch 938, minibatch 1/1, validation error 8.000000 %
# epoch 939, minibatch 1/1, validation error 8.000000 %
# epoch 940, minibatch 1/1, validation error 8.000000 %
# epoch 941, minibatch 1/1, validation error 8.000000 %
# epoch 942, minibatch 1/1, validation error 8.000000 %
# epoch 943, minibatch 1/1, validation error 8.000000 %
# epoch 944, minibatch 1/1, validation error 8.000000 %
# epoch 945, minibatch 1/1, validation error 8.000000 %
# epoch 946, minibatch 1/1, validation error 8.000000 %
# epoch 947, minibatch 1/1, validation error 8.000000 %
# epoch 948, minibatch 1/1, validation error 8.000000 %
# epoch 949, minibatch 1/1, validation error 8.000000 %
# epoch 950, minibatch 1/1, validation error 8.000000 %
# epoch 951, minibatch 1/1, validation error 8.000000 %
# epoch 952, minibatch 1/1, validation error 8.000000 %
# epoch 953, minibatch 1/1, validation error 8.000000 %
# epoch 954, minibatch 1/1, validation error 8.000000 %
# epoch 955, minibatch 1/1, validation error 8.000000 %
# epoch 956, minibatch 1/1, validation error 8.000000 %
# epoch 957, minibatch 1/1, validation error 8.000000 %
# epoch 958, minibatch 1/1, validation error 8.000000 %
# epoch 959, minibatch 1/1, validation error 8.000000 %
# epoch 960, minibatch 1/1, validation error 8.000000 %
# epoch 961, minibatch 1/1, validation error 8.000000 %
# epoch 962, minibatch 1/1, validation error 8.000000 %
# epoch 963, minibatch 1/1, validation error 8.000000 %
# epoch 964, minibatch 1/1, validation error 8.000000 %
# epoch 965, minibatch 1/1, validation error 8.000000 %
# epoch 966, minibatch 1/1, validation error 8.000000 %
# epoch 967, minibatch 1/1, validation error 8.000000 %
# epoch 968, minibatch 1/1, validation error 8.000000 %
# epoch 969, minibatch 1/1, validation error 8.000000 %
# epoch 970, minibatch 1/1, validation error 8.000000 %
# epoch 971, minibatch 1/1, validation error 8.000000 %
# epoch 972, minibatch 1/1, validation error 8.000000 %
# epoch 973, minibatch 1/1, validation error 8.000000 %
# epoch 974, minibatch 1/1, validation error 8.000000 %
# epoch 975, minibatch 1/1, validation error 8.000000 %
# epoch 976, minibatch 1/1, validation error 8.000000 %
# epoch 977, minibatch 1/1, validation error 8.000000 %
# epoch 978, minibatch 1/1, validation error 8.000000 %
# epoch 979, minibatch 1/1, validation error 8.000000 %
# epoch 980, minibatch 1/1, validation error 8.000000 %
# epoch 981, minibatch 1/1, validation error 8.000000 %
# epoch 982, minibatch 1/1, validation error 8.000000 %
# epoch 983, minibatch 1/1, validation error 8.000000 %
# epoch 984, minibatch 1/1, validation error 8.000000 %
# epoch 985, minibatch 1/1, validation error 8.000000 %
# epoch 986, minibatch 1/1, validation error 8.000000 %
# epoch 987, minibatch 1/1, validation error 8.000000 %
# epoch 988, minibatch 1/1, validation error 8.000000 %
# epoch 989, minibatch 1/1, validation error 8.000000 %
# epoch 990, minibatch 1/1, validation error 8.000000 %
# epoch 991, minibatch 1/1, validation error 8.000000 %
# epoch 992, minibatch 1/1, validation error 8.000000 %
# epoch 993, minibatch 1/1, validation error 7.333333 %
# epoch 994, minibatch 1/1, validation error 7.333333 %
# epoch 995, minibatch 1/1, validation error 7.333333 %
# epoch 996, minibatch 1/1, validation error 7.333333 %
# epoch 997, minibatch 1/1, validation error 7.333333 %
# epoch 998, minibatch 1/1, validation error 7.333333 %
# epoch 999, minibatch 1/1, validation error 7.333333 %
# epoch 1000, minibatch 1/1, validation error 7.333333 %
